# %% [markdown]
# # Make sure to set runtime to GPU to speed up hyperparameter optimization

# %%
# !pip install --upgrade keras==2.15.0
# !pip install --upgrade tensorflow==2.15.0.post1
# !pip install --upgrade scipy==1.11.4
# !pip install tensorflow-addons==0.21.0
# !pip install keras-tuner --upgrade

# clone minape repository, refresh folder to see the minape repository
# runtime -> change runtime -> choose gpu/tpu
# !git clone https://github.com/hubtru/Minape
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5
# Cloning into 'Minape'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 131 (delta 0), reused 3 (delta 0), pack-reused 128
# Receiving objects: 100% (131/131), 47.82 MiB | 28.25 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
from tensorflow import keras as k
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import array_to_img
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, concatenate
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import tensorflow_addons as tfa
import keras_tuner

os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
#Variables
image_size = 256
in_channel_spec = 9
num_classes = 3
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 40
num_epochs = 100

# %%
#Functions
#Multimodal implementation of Trockman, A., & Kolter, J. Z. (2022). Patches are all you need?.
#https://github.com/locuslab/convmixer
#Convert images to numpy array
def read_specs(file_paths_x, file_paths_y, file_paths_z, image_size, channels):
  images = []

  for i in range(file_paths_x.size):
    img_x = cv2.imread(file_paths_x[i])
    res_x = cv2.resize(img_x, dsize=(image_size, image_size), interpolation=cv2.INTER_CUBIC)
    images.append(res_x)
    img_y = cv2.imread(file_paths_y[i])
    res_y = cv2.resize(img_y, dsize=(image_size, image_size), interpolation=cv2.INTER_CUBIC)
    images.append(res_y)
    img_z = cv2.imread(file_paths_z[i])
    res_z = cv2.resize(img_z, dsize=(image_size, image_size), interpolation=cv2.INTER_CUBIC)
    images.append(res_z)

  images = np.asarray(images, dtype=np.float32)
  images = images / np.max(images)
  images = images.reshape(file_paths_x.shape[0], image_size, image_size, channels)

  return images

#Patch dataset

def generate_datasets(images, is_train=False):
    dataset = images
    if is_train:
        dataset = dataset.shuffle(batch_size * 10)
    dataset = dataset.batch(batch_size)
    if is_train:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x), y), num_parallel_calls=auto
        )
    return dataset.prefetch(auto)

#Model creation methods

def activation_module(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def base_module(x, filters, patch_size):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_module(x)


def multi_mixer_module(x, filters, kernel_size):
    # Depthwise convolution.
    x0 = x
    x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
    x = layers.Add()([activation_module(x), x0])  # Residual.

    # Pointwise convolution.
    x = layers.Conv2D(filters, kernel_size=1)(x)
    x = activation_module(x)

    return x


def load_multi_mixer(hp):

    filters=hp.Int("filters", min_value=128, max_value=512, step=128)
    depth=hp.Int("depth", min_value=4, max_value=8, step=4)
    kernel_size=hp.Int("kernel_size", min_value=3, max_value=9, step=1)
    patch_size=hp.Int("patch_size", min_value=4, max_value=32, step=4)

    inputs = k.Input((image_size, image_size, in_channel_spec))
    x = layers.Rescaling(scale=1.0 / 255)(inputs)

    # Extract patch embeddings.
    x = base_module(x, filters, patch_size)

    # Multi_mixer blocks.
    for _ in range(depth):
        x = multi_mixer_module(x, filters, kernel_size)

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = k.Model(inputs, outputs)

    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

#Run experiment

def launch_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = k.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        new_train_dataset,
        validation_data=new_val_dataset,
        epochs=num_epochs,
        shuffle=True,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy = model.evaluate(new_test_dataset)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, model

# %%
#Dataset acquisition

#Augmented dataset
    #Random distribution
data_path = '/content/Minape/Data/labels_aug/random_distribution'
train_df = pd.read_csv(f'{data_path}/train.csv', index_col=0)
test_df = pd.read_csv(f'{data_path}/test.csv', index_col=0)
val_df = pd.read_csv(f'{data_path}/val.csv', index_col=0)
    #Tool distribution
# data_path = '/content/Minape/Data/labels_aug/tool_distribution'
# train_df = pd.read_csv(f'{data_path}/train.csv', index_col=0)
# test_df = pd.read_csv(f'{data_path}/test.csv', index_col=0)
# val_df = pd.read_csv(f'{data_path}/val.csv', index_col=0)

spec_path = '/content/Minape/Data/dataset_aug'
train_df['spec_x'] = train_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')
test_df['spec_x'] = test_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')
val_df['spec_x'] = val_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')

train_df['spec_y'] = train_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')
test_df['spec_y'] = test_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')
val_df['spec_y'] = val_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')

train_df['spec_z'] = train_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')
test_df['spec_z'] = test_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')
val_df['spec_z'] = val_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')

#Original dataset
    #Random distribution
# data_path = '/content/Minape/Data/labels_original/random_distribution'
# train_df = pd.read_csv(f'{data_path}/train.csv', index_col=0)
# test_df = pd.read_csv(f'{data_path}/test.csv', index_col=0)
# val_df = pd.read_csv(f'{data_path}/val.csv', index_col=0)

    #Tool distribution
# data_path = '/content/Minape/Data/labels_original/tool_distribution'
# train_df = pd.read_csv(f'{data_path}/train.csv', index_col=0)
# test_df = pd.read_csv(f'{data_path}/test.csv', index_col=0)
# val_df = pd.read_csv(f'{data_path}/val.csv', index_col=0)

# spec_path = '/content/Minape/Data/dataset_original'
# train_df['spec_x'] = train_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')
# test_df['spec_x'] = test_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')
# val_df['spec_x'] = val_df.index.map(lambda id: f'{spec_path}/specX/{id}.png')

# train_df['spec_y'] = train_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')
# test_df['spec_y'] = test_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')
# val_df['spec_y'] = val_df.index.map(lambda id: f'{spec_path}/specY/{id}.png')

# train_df['spec_z'] = train_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')
# test_df['spec_z'] = test_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')
# val_df['spec_z'] = val_df.index.map(lambda id: f'{spec_path}/specZ/{id}.png')

# %%
#Plot dataset distribution
plt.figure(figsize=(6,6))
sns.displot(train_df['tool_label'])
plt.title('Label Distribution')
plt.show()

# %%
#Read spectrograms and convert them to NumPy array
x_train_spec = read_specs(train_df.spec_x.values,train_df.spec_y.values,train_df.spec_z.values, image_size, in_channel_spec)
x_test_spec = read_specs(test_df.spec_x.values,test_df.spec_y.values,test_df.spec_z.values, image_size, in_channel_spec)
x_val_spec = read_specs(val_df.spec_x.values,val_df.spec_y.values,val_df.spec_z.values, image_size, in_channel_spec)
#Bring the labels to an acceptable form
labels_train = train_df.tool_label.values - 1
labels_test = test_df.tool_label.values - 1
labels_val = val_df.tool_label.values - 1

# %%
#Create tensorflow datasets objects and add patch embedding to train dataset
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_spec, labels_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_spec, labels_test))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_spec, labels_val))
train_dataset = train_dataset.shuffle(x_train_spec.shape[0], seed=777)

auto = tf.data.AUTOTUNE

data_augmentation = k.Sequential(
    [layers.RandomCrop(image_size, image_size), k.layers.RandomFlip("horizontal"),],
    name="data_augmentation",
)

new_train_dataset = generate_datasets(train_dataset, is_train=True)
new_val_dataset = generate_datasets(val_dataset)
new_test_dataset = generate_datasets(test_dataset)

# %%
#Multi_mixer model architecture optimization
hp = keras_tuner.HyperParameters()

tuner = keras_tuner.RandomSearch(
    hypermodel=load_multi_mixer,
    objective="val_accuracy",
    max_trials=100,
    seed=None,
    hyperparameters=None,
    tune_new_entries=True,
    allow_new_entries=True,
    overwrite=True,
    project_name="tool_opt"
)

history_opt = tuner.search(
        new_train_dataset,
        epochs=num_epochs,
        shuffle=True,
        validation_data=new_val_dataset
    )
# Out:
# Trial 100 Complete [00h 00m 30s]
# val_accuracy: 0.3333333432674408
#
# Best val_accuracy So Far: 0.6666666865348816
# Total elapsed time: 01h 08m 06s

# %%
#Optimization summary #1
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# filters (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 512, 'step': 128, 'sampling': 'linear'}
# depth (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 8, 'step': 4, 'sampling': 'linear'}
# kernel_size (Int)
# {'default': None, 'conditions': [], 'min_value': 3, 'max_value': 9, 'step': 1, 'sampling': 'linear'}
# patch_size (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 32, 'step': 4, 'sampling': 'linear'}

# %%
#Optimization summary #2
tuner.results_summary()
# Out:
# Results summary
# Results in ./tool_opt
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 019 summary
# Hyperparameters:
# filters: 128
# depth: 4
# kernel_size: 6
# patch_size: 32
# Score: 0.6666666865348816
#
# Trial 092 summary
# Hyperparameters:
# filters: 256
# depth: 4
# kernel_size: 5
# patch_size: 24
# Score: 0.6666666865348816
#
# Trial 000 summary
# Hyperparameters:
# filters: 512
# depth: 4
# kernel_size: 4
# patch_size: 8
# Score: 0.3333333432674408
#
# Trial 001 summary
# Hyperparameters:
# filters: 128
# depth: 4
# kernel_size: 3
# patch_size: 16
# Score: 0.3333333432674408
#
# Trial 002 summary
# Hyperparameters:
# filters: 256
# depth: 8
# kernel_size: 6
# patch_size: 28
# Score: 0.3333333432674408
#
# Trial 003 summary
# Hyperparameters:
# filters: 512
# depth: 4
# kernel_size: 4
# patch_size: 20
# Score: 0.3333333432674408
#
# Trial 004 summary
# Hyperparameters:
# filters: 256
# depth: 8
# kernel_size: 5
# patch_size: 28
# Score: 0.3333333432674408
#
# Trial 005 summary
# Hyperparameters:
# filters: 256
# depth: 4
# kernel_size: 6
# patch_size: 16
# Score: 0.3333333432674408
#
# Trial 006 summary
# Hyperparameters:
# filters: 128
# depth: 4
# kernel_size: 7
# patch_size: 20
# Score: 0.3333333432674408
#
# Trial 007 summary
# Hyperparameters:
# filters: 256
# depth: 4
# kernel_size: 5
# patch_size: 4
# Score: 0.3333333432674408

# %%
#Choose the best model based on architecture optimization
models = tuner.get_best_models(num_models=2)
best_model = models[0]
best_model.build(input_shape=(image_size, image_size, in_channel_spec))
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 9)]        0         []
#
#  rescaling (Rescaling)       (None, 256, 256, 9)          0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, 8, 8, 128)            1179776   ['rescaling[0][0]']
#
#  activation (Activation)     (None, 8, 8, 128)            0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 8, 8, 128)            512       ['activation[0][0]']
#  Normalization)
#
#  depthwise_conv2d (Depthwis  (None, 8, 8, 128)            4736      ['batch_normalization[0][0]']
#  eConv2D)
#
#  activation_1 (Activation)   (None, 8, 8, 128)            0         ['depthwise_conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 8, 8, 128)            512       ['activation_1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 8, 8, 128)            0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)            16512     ['add[0][0]']
#
#  activation_2 (Activation)   (None, 8, 8, 128)            0         ['conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 8, 8, 128)            512       ['activation_2[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_1 (Depthw  (None, 8, 8, 128)            4736      ['batch_normalization_2[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_3 (Activation)   (None, 8, 8, 128)            0         ['depthwise_conv2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 8, 8, 128)            512       ['activation_3[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 8, 8, 128)            0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)            16512     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 8, 8, 128)            0         ['conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)            512       ['activation_4[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_2 (Depthw  (None, 8, 8, 128)            4736      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_5 (Activation)   (None, 8, 8, 128)            0         ['depthwise_conv2d_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)            512       ['activation_5[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 8, 8, 128)            0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)            16512     ['add_2[0][0]']
#
#  activation_6 (Activation)   (None, 8, 8, 128)            0         ['conv2d_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 8, 8, 128)            512       ['activation_6[0][0]']
#  chNormalization)
#
#  depthwise_conv2d_3 (Depthw  (None, 8, 8, 128)            4736      ['batch_normalization_6[0][0]'
#  iseConv2D)                                                         ]
#
#  activation_7 (Activation)   (None, 8, 8, 128)            0         ['depthwise_conv2d_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 8, 8, 128)            512       ['activation_7[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 8, 8, 128)            0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)            16512     ['add_3[0][0]']
#
#  activation_8 (Activation)   (None, 8, 8, 128)            0         ['conv2d_4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 8, 8, 128)            512       ['activation_8[0][0]']
#  chNormalization)
#
#  global_average_pooling2d (  (None, 128)                  0         ['batch_normalization_8[0][0]'
#  GlobalAveragePooling2D)                                            ]
#
#  dense (Dense)               (None, 3)                    387       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 1269763 (4.84 MB)
# Trainable params: 1267459 (4.83 MB)
# Non-trainable params: 2304 (9.00 KB)
# __________________________________________________________________________________________________

# %%
#Choose the best hyperparameters
best_hps = tuner.get_best_hyperparameters(5)
model = load_multi_mixer(best_hps[0])

# %%
#Train optimized architecture
history, conv_mixer_model = launch_experiment(model)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0065 - accuracy: 0.6667 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 2/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.5014 - accuracy: 1.0000 - val_loss: 1.0989 - val_accuracy: 0.3333
# Epoch 3/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.1320 - accuracy: 1.0000 - val_loss: 1.0997 - val_accuracy: 0.3333
# Epoch 4/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 1.1012 - val_accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 1.1033 - val_accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 1.1061 - val_accuracy: 0.3333
# Epoch 7/100
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.1096 - val_accuracy: 0.3333
# Epoch 8/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.1138 - val_accuracy: 0.3333
# Epoch 9/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1188 - val_accuracy: 0.3333
# Epoch 10/100
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.1244 - val_accuracy: 0.3333
# Epoch 11/100
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1308 - val_accuracy: 0.3333
# Epoch 12/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1379 - val_accuracy: 0.3333
# Epoch 13/100
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.1457 - val_accuracy: 0.3333
# Epoch 14/100
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.1541 - val_accuracy: 0.3333
# Epoch 15/100
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1631 - val_accuracy: 0.3333
# Epoch 16/100
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1727 - val_accuracy: 0.3333
# Epoch 17/100
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1829 - val_accuracy: 0.3333
# Epoch 18/100
# 1/1 [==============================] - 0s 116ms/step - loss: 9.1154e-04 - accuracy: 1.0000 - val_loss: 1.1936 - val_accuracy: 0.3333
# Epoch 19/100
# 1/1 [==============================] - 0s 122ms/step - loss: 8.0551e-04 - accuracy: 1.0000 - val_loss: 1.2048 - val_accuracy: 0.3333
# Epoch 20/100
# 1/1 [==============================] - 0s 126ms/step - loss: 7.3588e-04 - accuracy: 1.0000 - val_loss: 1.2164 - val_accuracy: 0.3333
# Epoch 21/100
# 1/1 [==============================] - 0s 121ms/step - loss: 6.4734e-04 - accuracy: 1.0000 - val_loss: 1.2284 - val_accuracy: 0.3333
# Epoch 22/100
# 1/1 [==============================] - 0s 118ms/step - loss: 5.8883e-04 - accuracy: 1.0000 - val_loss: 1.2408 - val_accuracy: 0.3333
# Epoch 23/100
# 1/1 [==============================] - 0s 130ms/step - loss: 5.5269e-04 - accuracy: 1.0000 - val_loss: 1.2535 - val_accuracy: 0.3333
# Epoch 24/100
# 1/1 [==============================] - 0s 143ms/step - loss: 5.1338e-04 - accuracy: 1.0000 - val_loss: 1.2665 - val_accuracy: 0.3333
# Epoch 25/100
# 1/1 [==============================] - 0s 183ms/step - loss: 1.3397e-04 - accuracy: 1.0000 - val_loss: 2.0147 - val_accuracy: 0.3333
# Epoch 84/100
# 1/1 [==============================] - 0s 173ms/step - loss: 1.3022e-04 - accuracy: 1.0000 - val_loss: 2.0249 - val_accuracy: 0.3333
# Epoch 85/100
# 1/1 [==============================] - 0s 176ms/step - loss: 1.3227e-04 - accuracy: 1.0000 - val_loss: 2.0350 - val_accuracy: 0.3333
# Epoch 86/100
# 1/1 [==============================] - 0s 182ms/step - loss: 1.2857e-04 - accuracy: 1.0000 - val_loss: 2.0451 - val_accuracy: 0.3333
# Epoch 87/100
# 1/1 [==============================] - 0s 179ms/step - loss: 1.3069e-04 - accuracy: 1.0000 - val_loss: 2.0551 - val_accuracy: 0.3333
# Epoch 88/100
# 1/1 [==============================] - 0s 158ms/step - loss: 1.3006e-04 - accuracy: 1.0000 - val_loss: 2.0650 - val_accuracy: 0.3333
# Epoch 89/100
# 1/1 [==============================] - 0s 122ms/step - loss: 1.2387e-04 - accuracy: 1.0000 - val_loss: 2.0749 - val_accuracy: 0.3333
# Epoch 90/100
# 1/1 [==============================] - 0s 126ms/step - loss: 1.2545e-04 - accuracy: 1.0000 - val_loss: 2.0846 - val_accuracy: 0.3333
# Epoch 91/100
# 1/1 [==============================] - 0s 125ms/step - loss: 1.2705e-04 - accuracy: 1.0000 - val_loss: 2.0943 - val_accuracy: 0.3333
# Epoch 92/100
# 1/1 [==============================] - 0s 129ms/step - loss: 1.2285e-04 - accuracy: 1.0000 - val_loss: 2.1039 - val_accuracy: 0.3333
# Epoch 93/100
# 1/1 [==============================] - 0s 134ms/step - loss: 1.2278e-04 - accuracy: 1.0000 - val_loss: 2.1134 - val_accuracy: 0.3333
# Epoch 94/100
# 1/1 [==============================] - 0s 129ms/step - loss: 1.1973e-04 - accuracy: 1.0000 - val_loss: 2.1228 - val_accuracy: 0.3333
# Epoch 95/100
# 1/1 [==============================] - 0s 124ms/step - loss: 1.2303e-04 - accuracy: 1.0000 - val_loss: 2.1323 - val_accuracy: 0.3333
# Epoch 96/100
# 1/1 [==============================] - 0s 122ms/step - loss: 1.2018e-04 - accuracy: 1.0000 - val_loss: 2.1416 - val_accuracy: 0.3333
# Epoch 97/100
# 1/1 [==============================] - 0s 130ms/step - loss: 1.2133e-04 - accuracy: 1.0000 - val_loss: 2.1508 - val_accuracy: 0.3333
# Epoch 98/100
# 1/1 [==============================] - 0s 132ms/step - loss: 1.1880e-04 - accuracy: 1.0000 - val_loss: 2.1600 - val_accuracy: 0.3333
# Epoch 99/100
# 1/1 [==============================] - 0s 140ms/step - loss: 1.1599e-04 - accuracy: 1.0000 - val_loss: 2.1692 - val_accuracy: 0.3333
# Epoch 100/100
# 1/1 [==============================] - 0s 127ms/step - loss: 1.1729e-04 - accuracy: 1.0000 - val_loss: 2.1782 - val_accuracy: 0.3333
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0986 - accuracy: 0.3333
# Test accuracy: 33.33%

# %%
#Save model
model_path = '/content/Minape/models_rep'
conv_mixer_model.save(f"{model_path}/spec_aug_tool_opt.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Plot accuracy history
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#Plot loss history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
